# %%
import pandas as pd

import seaborn as sns
#Load the data
titanic = sns.load_dataset('titanic')


# Load the Titanic dataset 
data = fetch_openml('titanic', version=1, as_frame=True)
df = data['data']
df
# Out:
# /usr/local/lib/python3.11/site-packages/sklearn/datasets/_openml.py:1002: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
#       pclass                                             name     sex  \
# 0        1.0                    Allen, Miss. Elisabeth Walton  female
# 1        1.0                   Allison, Master. Hudson Trevor    male
# 2        1.0                     Allison, Miss. Helen Loraine  female
# 3        1.0             Allison, Mr. Hudson Joshua Creighton    male
# 4        1.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# ...

# %%
# Task a: Find the total number of passengers with age less than 30
total_passengers_less_than_30 = df[df['age'] < 30]['age'].count()
print("Total passengers with age less than 30:", total_passengers_less_than_30)

print(df.columns.values)

# Task c: Compare the number of survivors of each passenger class
survivors_by_class = df.groupby('pclass')['survived'].sum()
print("Number of survivors by passenger class:\n", survivors_by_class)

# Task d: Compute descriptive statistics for any numeric attribute gender-wise
genderwise_stats = df.groupby('sex').describe()
print("Descriptive statistics by gender:\n", genderwise_stats)
# Out:
# Total passengers with age less than 30: 569
# ['pclass' 'name' 'sex' 'age' 'sibsp' 'parch' 'ticket' 'fare' 'cabin'
#  'embarked' 'boat' 'body' 'home.dest']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 8
#       5 print(df.columns.values)
#       7 # Task c: Compare the number of survivors of each passenger class
# ----> 8 survivors_by_class = df.groupby('pclass')['survived'].sum()
#       9 print("Number of survivors by passenger class:\n", survivors_by_class)
#      11 # Task d: Compute descriptive statistics for any numeric attribute gender-wise
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1771, in DataFrameGroupBy.__getitem__(self, key)
#    1764 if isinstance(key, tuple) and len(key) > 1:
#    1765     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1766     # valid syntax, so don't raise
# ...
